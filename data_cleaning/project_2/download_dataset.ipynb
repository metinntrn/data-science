# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sunil123kumar/social-media-impact-on-mental-health")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/exa/.cache/kagglehub/datasets/sunil123kumar/social-media-impact-on-mental-health/1.archive...
# 100%|██████████| 15.8k/15.8k [00:00<00:00, 10.1MB/s]
# Extracting files...
# Path to dataset files: /home/exa/.cache/kagglehub/datasets/sunil123kumar/social-media-impact-on-mental-health/versions/1
